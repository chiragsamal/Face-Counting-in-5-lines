# %% [markdown]
# ## Face Counting

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import cv2

# %%
#mtcnn required
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 2.8MB/s
# ...

# %%
from mtcnn import MTCNN

# %%
model = MTCNN()

# %%
#importing image using opencv
img = cv2.imread("/content/ey-staff-at-event.jpg")

# %%
result = model.detect_faces(img)

# %%
#Number of faces in a image
print("The imported picture contains {} perons".format(len(result)))
# Out:
# The imported picture contains 214 perons

# %%
def show_faces(result):
    for i in range(len(result)):
        x1, y1, width, height = result[i]['box']
        x1, y1 = abs(x1), abs(y1)
        x2, y2 = x1 + width, y1 + height
        pic = cv2.rectangle(img,(x1,y1),(x2,y2),(0,0,255),5) #draws a  red rectangle around the face
    return pic

# %%
pic = show_faces(result)
pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
plt.imshow(pic)
plt.savefig('result.png')
